# %% [markdown]
# # Topic Modeling Lab
# ## Contents
# 1. [Setup](#Section-1%3A-Setup)
#     1. [Import](#1.1-Import-Packages)
#     1. [Download](#1.2-Download-and-Prepare-Data)
#     1. [Read](#1.3-Read-Data)
#     1. [Pick Your Data](#1.4-Pick-Your-Data)
#     1. [Clean Text](#1.5-Clean-Text)
# 1. [Converting Text to Numbers](#Section-2%3A-Converting-Text-to-Numbers)
# 1. [LDA Topic Model](#Section-3%3A-LDA-Topic-Model)
# 1. [Interpret Topics](#Section-4%3A-Interpret-Topics)
# 1. [Topic Quality](#Section-5%3A-Topic-Quality)
# 1. [Topic Popularity](#Section-6%3A-Topic-Popularity)
# 1. [NMF Topic Model](#Section-7%3A-NMF-Topic-Model)
# 1. [What We Learned](#Section-7%3A-What-We-Learned)
#
# ## Section 0: Background
# - In this lab, we'll learn about topic modeling. Topic modeling uses statistics to understand what text is about, that is, to find the topics in text.
# - We'll use the online dating profile text that OKCupid made public as our example, but of course topic modeling can be used on any text.
#
# @Author: [Jeff Lockhart](http://www-personal.umich.edu/~jwlock/) & [Ed Platt](https://elplatt.com/), with some code adapted from [Aneesha Bakharia](https://medium.com/@aneesha/topic-modeling-with-scikit-learn-e80d33668730)'s example.

# %% [markdown]
# ## Section 1: Setup
# ### 1.1 Import Packages
# - Packages contain code others have written to make our work easier.

# %%
import pandas as pd
import numpy as np
import pickle
#from tqdm import tqdm
#tqdm.pandas()
from scipy.stats.stats import pearsonr  
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.metrics.pairwise import cosine_similarity
#from bs4 import BeautifulSoup
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1.2 Download and Prepare Data
# This code checks whether you have the data. If you don't, it will download and prepare it for you. To see how it works, look at lab `1 Data munging` which explains it in detail.

# %%
#%run -i 'download_and_clean_data.py'
#print('Ready to go!')

# %% [markdown]
# ### 1.3 Read Data

# %%
seed = 2019

# %%
profiles = pd.read_csv('data/cleaned_profiles.csv').dropna(subset=['essay0'])
profiles.head(2)
# Out:
#    Unnamed: 0  age       body_type               diet    drinks  drugs  \
# 0           0   22  a little extra  strictly anything  socially  never
# 1           3   23            thin         vegetarian  socially    NaN
#
#                        education  \
# 0  working on college/university
# 1  working on college/university
#
#                                               essay0  \
# 0  about me:i would love to think that i was some...
# 1          i work in a library and go to school. . .
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1          reading things written by old dead people
#
#                                               essay2      ...       \
# 0  making people laugh.<br />\r\nranting about a ...      ...
# 1  playing synthesizers and organizing books acco...      ...
#
#                                 religion sex    sign     smokes  \
# 0  agnosticism and very serious about it   m  gemini  sometimes
# 1                                    NaN   m  pisces         no
#
#                      speaks  status                  edu      fit  \
# 0                   english  single  High School or less  not_fit
# 1  english, german (poorly)  single  High School or less  not_fit
#
#    race_ethnicity  height_group
# 0        multiple     not_short
# 1           White     not_short
#
# [2 rows x 36 columns]

# %%
pd.crosstab(index=profiles['edu'],  # Make a crosstab
                        columns="count")
# Out:
# col_0                  count
# edu
# High School or less     3217
# More than High School  13583
# unknown                 2030

# %%
pd.crosstab(index=profiles['fit'],  # Make a crosstab
                        columns="count")
# Out:
# col_0    count
# fit
# fit      10542
# not_fit   8236
# unknown     52

# %%
pd.crosstab(index=profiles['race_ethnicity'],  # Make a crosstab
                        columns="count")
# Out:
# col_0           count
# race_ethnicity
# Asian            2661
# Black             640
# Latinx           1730
# White           11727
# multiple         1337
# other             735

# %%
pd.crosstab(index=profiles['height_group'],  # Make a crosstab
                        columns="count")
# Out:
# col_0         count
# height_group
# not_short     12210
# short          6620

# %% [markdown]
# ### 1.4 Pick Your Data
# - Pick which section of the profiles you want to analyze.
# #### Options:
# - `text` - All of the text from a profile (**Recommended**)
# - `essay0` - My self summary (**Recommended**)
# - `essay1` - What I’m doing with my life
# - `essay2` - I’m really good at
# - `essay3` - The first thing people usually notice about me
# - `essay4` - Favorite books, movies, show, music, and food
# - `essay5` - The six things I could never do without
# - `essay6` - I spend a lot of time thinking about
# - `essay7` - On a typical Friday night I am
# - `essay8` - The most private thing I am willing to admit
# - `essay9` - You should message me if...
#
# #### Replace `essay0` in the cell below with the essay you want to look at.
# - `text` and `essay0` are both recommended, but it's your choice.

# %%
profile_section_to_use = 'essay0'

# %%
documents = profiles[profile_section_to_use]

# %% [markdown]
# ### 1.5 Clean Text
# - For this lab, it is not so important that you understand this code.
# - For now, just run it and move on.

# %% [markdown]
# ## Section 2: Converting Text to Numbers
# - Our first model takes "count vectors" as input, that is, a count of how many times each word shows up in each document.
#     - Here we tell it to only use the 1,000 most popular words, ignoring stop words like "a" and "of".
#     - We use the abbreviation `tf` for these because they represent "text frequency," i.e., how often each word shows up in text.

# %%
profiles
# Out:
#        Unnamed: 0  age       body_type                 diet      drinks  \
# 0               0   22  a little extra    strictly anything    socially
# 1               3   23            thin           vegetarian    socially
# 2               5   29         average      mostly anything    socially
# 3               9   37        athletic      mostly anything  not at all
# 4              11   28         average      mostly anything    socially
# 5              16   33             fit                  NaN    socially
# 6              18   31         average    mostly vegetarian      rarely
# 7              19   33        athletic      mostly anything    socially
# 8              22   30             fit      mostly anything    socially
# 9              23   30            thin       strictly vegan  not at all
# 10             24   33            thin    strictly anything    socially
# 11             25   28             fit             anything      rarely
# 12             26   22             fit      mostly anything    socially
# 13             36   32        athletic      mostly anything    socially
# 14             39   35             fit                  NaN    socially
# 15             41   35        athletic    strictly anything         NaN
# 16             43   40             fit                  NaN    socially
# 17             52   31         average      mostly anything    socially
# 18             56   26             fit             anything    socially
# 19             57   21            thin                  NaN    socially
# 20             60   31             fit      mostly anything    socially
# 21             65   29             fit    mostly vegetarian    socially
# 22             66   22        athletic      mostly anything      rarely
# 23             72   35        athletic      mostly anything    socially
# 24             74   28             fit    strictly anything         NaN
# 25             76   26             fit      mostly anything       often
# 26             79   21             fit      mostly anything      rarely
# 27             82   34             fit             anything    socially
# 28             85   28         average                  NaN    socially
# 29             90   24         average             anything    socially
# ...           ...  ...             ...                  ...         ...
# 18801       60389   26        athletic      mostly anything    socially
# 18802       60390   41            thin             anything  not at all
# 18803       60392   29         average             anything    socially
# 18804       60398   25         average             anything    socially
# 18805       60401   26             fit             anything    socially
# 18806       60405   33             fit                  NaN    socially
# 18807       60419   42             fit                  NaN    socially
# 18808       60438   24         average                  NaN    socially
# 18809       60439   24  a little extra             anything       often
# 18810       60444   33             fit      mostly anything    socially
# 18811       60445   48         average                  NaN      rarely
# 18812       60465   31        athletic      mostly anything       often
# 18813       60466   51         average      mostly anything      rarely
# 18814       60472   29         average      mostly anything    socially
# 18815       60474   32        athletic                  NaN    socially
# 18816       60478   33             fit             anything    socially
# 18817       60481   19         average    mostly vegetarian      rarely
# 18818       60484   25         average                  NaN    socially
# 18819       60486   25        athletic      mostly anything    socially
# 18820       60498   30            thin      mostly anything    socially
# 18821       60500   32         average      mostly anything    socially
# 18822       60513   24          skinny             anything    socially
# 18823       60523   26             fit      mostly anything    socially
# 18824       60529   22      overweight    strictly anything    socially
# 18825       60534   29         average      mostly anything    socially
# 18826       60535   27         average  strictly vegetarian    socially
# 18827       60537   24             fit  strictly vegetarian      rarely
# 18828       60548   24             fit      mostly anything       often
# 18829       60549   42         average      mostly anything  not at all
# 18830       60550   27        athletic      mostly anything    socially
#
#            drugs                          education  \
# 0          never      working on college/university
# 1            NaN      working on college/university
# 2            NaN  graduated from college/university
# 3          never        working on two-year college
# 4          never  graduated from college/university
# 5            NaN         working on masters program
# 6          never          graduated from space camp
# 7          never     graduated from masters program
# 8          never  graduated from college/university
# 9          never  graduated from college/university
# 10     sometimes  graduated from college/university
# 11         never  graduated from college/university
# 12         never      working on college/university
# 13         never  graduated from college/university
# 14           NaN  graduated from college/university
# 15           NaN  graduated from college/university
# 16           NaN  graduated from college/university
# 17           NaN  graduated from college/university
# 18           NaN      working on college/university
# 19           NaN      working on college/university
# 20         never      working on college/university
# 21         never        graduated from ph.d program
# 22         never      working on college/university
# 23     sometimes          graduated from space camp
# 24           NaN     graduated from masters program
# 25     sometimes            working on ph.d program
# 26         never      working on college/university
# 27         never     graduated from masters program
# 28           NaN  graduated from college/university
# 29         never  graduated from college/university
# ...          ...                                ...
# 18801      never  graduated from college/university
# 18802  sometimes  graduated from college/university
# 18803      never  graduated from college/university
# 18804        NaN  graduated from college/university
# 18805  sometimes            working on ph.d program
# 18806        NaN  graduated from college/university
# 18807        NaN  graduated from college/university
# 18808      never  graduated from college/university
# 18809      never         working on masters program
# 18810  sometimes        graduated from ph.d program
# 18811      never    graduated from two-year college
# 18812  sometimes         working on masters program
# 18813      never     graduated from masters program
# 18814      never  graduated from college/university
# 18815        NaN  graduated from college/university
# 18816      never          graduated from med school
# 18817      never        working on two-year college
# 18818      never              working on med school
# 18819      never              working on med school
# 18820  sometimes     graduated from masters program
# 18821  sometimes              working on space camp
# 18822  sometimes  graduated from college/university
# 18823      never     graduated from masters program
# 18824      never        working on two-year college
# 18825      never  graduated from college/university
# 18826  sometimes     graduated from masters program
# 18827      never  graduated from college/university
# 18828  sometimes      working on college/university
# 18829      never     graduated from masters program
# 18830      often      working on college/university
#
#                                                   essay0  \
# 0      about me:i would love to think that i was some...
# 1              i work in a library and go to school. . .
# 2      i'm an australian living in san francisco, but...
# 3      my names jake.i'm a creative guy and i look fo...
# 4      i was born in wisconsin, grew up in iowa, and ...
# 5      i just moved to the bay area from austin, tx (...
# 6      some of my favorite things:riding my motorcycl...
# 7      i relocated to san francisco half a year ago. ...
# 8      i tend to think the same way a comedian does a...
# 9      here's a completely fake summary i wrote while...
# 10     bay area transplant six years or so now, strai...
# 11     hey to all, hope all is well and your having a...
# 12     full-time student, full-time square. i change ...
# 13     i lost a needle in a haystack once....and foun...
# 14     i love life!oh. okcupid is telling me that thr...
# 15     -i grew up in new york and san diego half and ...
# 16     i don't really like summarizing myself; but wh...
# 17     i'm a free culture nerd. i travel, talk, and t...
# 18     originally from france, lived in 3 different c...
# 19     i grew up in iowa. it gets a bad rap, but let ...
# 20     straight to the point! i sugar coat, but i mea...
# 21     i really like meeting new people. small-world ...
# 22     it will be way too boring to just reveal yours...
# 23     i'm an adventurer first, i take calculatedrisk...
# 24     i can be extroverted and charming and yet enjo...
# 25     raised by a sailor and a taxidermist in the pa...
# 26     originally from southern california, moved up ...
# 27     i moved to sf ~7 months ago, and so far i'm re...
# 28     like everyone else on this site, i feel awkwar...
# 29              mmmmmm idk what to say so just ask me :)
# ...                                                  ...
# 18801  went to college in colorado. went to san diego...
# 18802  i am spending the next two years+ pursuing my ...
# 18803  i live in san francisco and if you're reading ...
# 18804                                    to be continued
# 18805  i'm a passionate guy that likes to engage in g...
# 18806  i love trying new restaurants, jogging, hiking...
# 18807  grew up in chicagomoved here in 1989i'm a thir...
# 18808  my name is troy and i was born and raised in n...
# 18809  i'm very friendly and i try to be outgoing and...
# 18810  hi! i'm dan. thanks for taking the time to che...
# 18811  i'm a seasoned seeker. i've been a working mus...
# 18812  a random character in the abyss. born in sf, r...
# 18813  i have had my fair share of adventures and int...
# 18814  according to myers-briggs typology i'm an intp...
# 18815  you can call me tio... i chase dough a roller....
# 18816  lazy hard worker, over-thinker and good mate. ...
# 18817  would you describe yourself as a very attracti...
# 18818  i like to try new things. i love going to new ...
# 18819  i'm really into dancing (salsa + ballroom). i ...
# 18820  i'm both sarcastic and sweet. i love seeing li...
# 18821  i try to lose my mind so i can come to my sens...
# 18822  my name is peter. i'm an oakland native, and i...
# 18823                         i am a master of mischief.
# 18824  i like hanging out with friends and meeting ne...
# 18825  i'm here to perhaps, meet new friends and to g...
# 18826  i like iced tea, old tv sets, wearing brown cl...
# 18827  born in southern india, grew up in dubai, live...
# 18828  i'm nick.i never know what to write about myse...
# 18829  hello! i enjoy traveling, watching movies, and...
# 18830  "all i have in this world are my balls and my ...
#
#                                                   essay1  \
# 0      currently working as an international agent fo...
# 1              reading things written by old dead people
# 2      building awesome stuff. figuring out what's im...
# 3      i have an apartment. i like to explore and che...
# 4      i'm currently the youngest member on an intern...
# 5      making music, programming, getting back into a...
# 6        enjoying it, exploring limits, looking for love
# 7      i left my comfort zone far behind in europe, a...
# 8      i'm a supply and demand manager for a sustaina...
# 9                i'm an english tutor and i love my job.
# 10     i don't work for $$ right now, just so you are...
# 11     always with my dog or spending time with famil...
# 12     i'm currently studying at ccsf. i went to babs...
# 13     after a 6 month backpacking trip through south...
# 14     <a class="ilink" href="/interests?i=design">de...
# 15                                                   NaN
# 16     spending a lot of time building things. a busi...
# 17     i've been rock climbing a lot lately. i've bee...
# 18     i am in school right now to learn more about h...
# 19     by day i'm an artist and computer scientist wo...
# 20     i'm a support engineer and have recently been ...
# 21     i'm a scientist of sorts, doing some interesti...
# 22                                           work+school
# 23     photography, lights, and sound. i also throw s...
# 24     i work at an elementary school in oakland as a...
# 25     i research cancer, with a lab coat and pipette...
# 26     im working on a degree in film at california s...
# 27     isn't this the million dollar question...<br /...
# 28     i recently got my degree in film and media, an...
# 29                                                   NaN
# ...                                                  ...
# 18801  i do like to stay on the move a lot, and go to...
# 18802  writing a screenplay with a friend. writing co...
# 18803  i work at a startup that i really like while a...
# 18804                             digital media analyst.
# 18805  i'm currently a graduate student in biochemist...
# 18806                                                NaN
# 18807  i work in a post-production studio mixing film...
# 18808  i studied aerospace science engineering at tus...
# 18809  currently doing an internship and working on a...
# 18810  about 10 years ago after receiving my bachelor...
# 18811  i am an instructor at <a class="ilink" href=\r...
# 18812  journalist, filmmaker, interactive media produ...
# 18813  learning to be a good uncle. finding gratitude...
# 18814  i work in san francisco, but outside of that i...
# 18815  well life's kinda leadin the way on this 1 but...
# 18816  med doc with a soul (for now and also if i do ...
# 18817  i'm only interested in those who are moving fo...
# 18818                                    medical school.
# 18819                                        eye surgery
# 18820  going to shows, enjoying life in sf, reading b...
# 18821  letting myself and my people be. lawyer by day...
# 18822  restaurant work downtown, (not enough) freelan...
# 18823  just recovering from suburban death in palo al...
# 18824  trying to get out of the staring contest i mad...
# 18825  recently finished college at ucb (go bears!) (...
# 18826  taking care of psychotics in halfway houses fo...
# 18827  working as a software engineer in san francisc...
# 18828  currently finishing school for film production...
# 18829  i'm a civil engineer, who enjoys helping the c...
# 18830  following my dreams...<br />\r\n"you got a dre...
#
#                                                   essay2      ...       \
# 0      making people laugh.<br />\r\nranting about a ...      ...
# 1      playing synthesizers and organizing books acco...      ...
# 2      imagining random shit. laughing at aforementio...      ...
# 3      i'm good at finding creative solutions to prob...      ...
# 4      i'm really good at a little bit of everything....      ...
# 5      i'm from louisiana, so cooking and eating are ...      ...
# 6      understanding, appreciating, i like getting a ...      ...
# 7      listening, connecting emotionally, analyzing t...      ...
# 8      making predictions, planning anything (i'm pre...      ...
# 9      i've made some really great <a class="ilink" h...      ...
# 10                                         hide and seek      ...
# 11     "living for today, in the moment"<br />\r\n<br...      ...
# 12     school, especially when there is a bet involve...      ...
# 13                 enjoying myself and being optimistic.      ...
# 14                                       most things :-p      ...
# 15     scrambling eggs<br />\r\ntaboo<br />\r\nobscur...      ...
# 16     designing and making things<br />\r\nusing my ...      ...
# 17             ping pong, mixing cocktails, and cooking.      ...
# 18     cooking/baking<br />\r\ntraveling<br />\r\nsee...      ...
# 19     getting lost (in a good way,) telling stories,...      ...
# 20                guess you'll have to see and find out.      ...
# 21     talking, if you get me on the right subject.<b...      ...
# 22                  making bad jokes and being sarcastic      ...
# 23     pretty much anything i put my mind to...<br />...      ...
# 24     getting along with almost anyone, reading, yog...      ...
# 25     cornhole. it's a game, played with clothes on ...      ...
# 26     i feel that i am very creative and artisitic. ...      ...
# 27     solving problems, whatever life throws at me, ...      ...
# 28     cracking wise, backrubs, wordplay, inventing n...      ...
# 29                                                   NaN      ...
# ...                                                  ...      ...
# 18801                                          executing      ...
# 18802                        making people feel at ease.      ...
# 18803  being optimistic, trying something new, hangin...      ...
# 18804  deriving humor from the mundane. outside-the-b...      ...
# 18805  bouncing quarters into a shot glass. and getti...      ...
# 18806                                                NaN      ...
# 18807  communicating,drumming, snowboarding, getting ...      ...
# 18808  thinking outside the box, logical analysis of ...      ...
# 18809  seeing the humor in everything, even things th...      ...
# 18810  <a class="ilink" href=\r\n"/interests?i=commun...      ...
# 18811  ...detecting a lie (though i may not say it)<b...      ...
# 18812  making people smile, reading emotions, being c...      ...
# 18813  crossing borders, finding parking spaces, empa...      ...
# 18814                        belittling my achievements.      ...
# 18815  whatever i chose to accomplish...football..rol...      ...
# 18816  reaching my goals<br />\r\ncooking<br />\r\ndo...      ...
# 18817  i really love a five course meal, the tastes o...      ...
# 18818                                i give good advice.      ...
# 18819  dancing. cars. sports<br />\r\nhere are some v...      ...
# 18820  ping-pong. handstands. getting to know people ...      ...
# 18821  not following good advice; making tea; contagi...      ...
# 18822  remaining calm, selecting music, baking pie, b...      ...
# 18823                                                NaN      ...
# 18824  having esoteric conversations about "q" from s...      ...
# 18825  cleanliness.<br />\r\nputting things in a list...      ...
# 18826  i am thinking of becoming a great cook.<br />\...      ...
# 18827  i enjoy biking, hiking, logic puzzles, jugglin...      ...
# 18828  <a class="ilink" href="/interests?i=filmmaking...      ...
# 18829  - looking at things objectively<br />\r\n- get...      ...
# 18830                                          listening      ...
#
#                                         religion sex  \
# 0          agnosticism and very serious about it   m
# 1                                            NaN   m
# 2                                        atheism   m
# 3                  atheism and laughing about it   m
# 4         christianity and very serious about it   m
# 5                                            NaN   m
# 6                                   christianity   m
# 7       catholicism but not too serious about it   m
# 8      agnosticism and somewhat serious about it   m
# 9                  atheism and laughing about it   m
# 10                                         other   m
# 11                                           NaN   m
# 12             catholicism and laughing about it   m
# 13         buddhism but not too serious about it   m
# 14                                           NaN   m
# 15                                   agnosticism   m
# 16      agnosticism but not too serious about it   m
# 17                                   agnosticism   m
# 18                 atheism and laughing about it   m
# 19                                      buddhism   m
# 20                                   catholicism   m
# 21          judaism but not too serious about it   m
# 22                buddhism and laughing about it   m
# 23         agnosticism and very serious about it   m
# 24                                           NaN   m
# 25                                   agnosticism   m
# 26      catholicism but not too serious about it   m
# 27                                   agnosticism   m
# 28          atheism but not too serious about it   m
# 29                                           NaN   m
# ...                                          ...  ..
# 18801                                        NaN   m
# 18802                                        NaN   m
# 18803                                        NaN   m
# 18804              atheism and laughing about it   m
# 18805         christianity and laughing about it   m
# 18806                                    atheism   m
# 18807                                        NaN   m
# 18808   catholicism but not too serious about it   m
# 18809  christianity but not too serious about it   m
# 18810              judaism and laughing about it   m
# 18811                other and laughing about it   m
# 18812                                   buddhism   m
# 18813                                        NaN   m
# 18814                other and laughing about it   m
# 18815                                        NaN   m
# 18816      buddhism but not too serious about it   m
# 18817      agnosticism and very serious about it   m
# 18818                                        NaN   m
# 18819                                        NaN   m
# 18820                                        NaN   m
# 18821              judaism and laughing about it   m
# 18822      atheism and somewhat serious about it   m
# 18823                                        NaN   m
# 18824            other and very serious about it   m
# 18825  christianity but not too serious about it   m
# 18826       atheism but not too serious about it   m
# 18827   agnosticism but not too serious about it   m
# 18828                                agnosticism   m
# 18829  christianity but not too serious about it   m
# 18830   agnosticism but not too serious about it   m
#
#                                                 sign          smokes  \
# 0                                             gemini       sometimes
# 1                                             pisces              no
# 2                                             taurus              no
# 3                 cancer but it doesn&rsquo;t matter              no
# 4                    leo but it doesn&rsquo;t matter              no
# 5                 pisces but it doesn&rsquo;t matter       sometimes
# 6                  libra but it doesn&rsquo;t matter              no
# 7           pisces and it&rsquo;s fun to think about              no
# 8            sagittarius but it doesn&rsquo;t matter              no
# 9               aquarius but it doesn&rsquo;t matter              no
# 10                      scorpio and it matters a lot       sometimes
# 11          gemini and it&rsquo;s fun to think about              no
# 12             leo and it&rsquo;s fun to think about  trying to quit
# 13          cancer and it&rsquo;s fun to think about   when drinking
# 14                                               NaN              no
# 15                                            pisces              no
# 16          gemini and it&rsquo;s fun to think about              no
# 17          gemini and it&rsquo;s fun to think about              no
# 18                                       sagittarius              no
# 19                                               NaN   when drinking
# 20                gemini but it doesn&rsquo;t matter              no
# 21                                               NaN              no
# 22                 virgo but it doesn&rsquo;t matter              no
# 23          pisces and it&rsquo;s fun to think about              no
# 24           sagittarius but it doesn&rsquo;t matter             NaN
# 25             capricorn but it doesn&rsquo;t matter              no
# 26                                               NaN              no
# 27                                               NaN              no
# 28         scorpio and it&rsquo;s fun to think about              no
# 29                                            cancer             yes
# ...                                              ...             ...
# 18801                                            NaN              no
# 18802             taurus but it doesn&rsquo;t matter       sometimes
# 18803             taurus but it doesn&rsquo;t matter              no
# 18804  sagittarius and it&rsquo;s fun to think about             yes
# 18805             gemini but it doesn&rsquo;t matter              no
# 18806                leo but it doesn&rsquo;t matter              no
# 18807          leo and it&rsquo;s fun to think about              no
# 18808        aries and it&rsquo;s fun to think about              no
# 18809                leo but it doesn&rsquo;t matter              no
# 18810       taurus and it&rsquo;s fun to think about              no
# 18811            scorpio but it doesn&rsquo;t matter              no
# 18812                                         pisces              no
# 18813                                         gemini              no
# 18814          capricorn but it doesn&rsquo;t matter              no
# 18815                                          aries             yes
# 18816                                            leo              no
# 18817       taurus and it&rsquo;s fun to think about              no
# 18818                                            NaN              no
# 18819            scorpio but it doesn&rsquo;t matter              no
# 18820        virgo and it&rsquo;s fun to think about   when drinking
# 18821                                            NaN       sometimes
# 18822       taurus and it&rsquo;s fun to think about       sometimes
# 18823     aquarius and it&rsquo;s fun to think about              no
# 18824                                            NaN       sometimes
# 18825     aquarius and it&rsquo;s fun to think about   when drinking
# 18826             pisces but it doesn&rsquo;t matter              no
# 18827                                            NaN              no
# 18828                leo but it doesn&rsquo;t matter              no
# 18829        sagittarius but it doesn&rsquo;t matter              no
# 18830          leo and it&rsquo;s fun to think about  trying to quit
#
#                                                   speaks          status  \
# 0                                                english          single
# 1                               english, german (poorly)          single
# 2                     english (fluently), chinese (okay)          single
# 3                                     english (fluently)          single
# 4             english (fluently), sign language (poorly)  seeing someone
# 5      english (fluently), c++ (fluently), german (po...          single
# 6                                     english (fluently)          single
# 7                                     english (fluently)          single
# 8                              english, spanish (poorly)          single
# 9                                                english          single
# 10                                               english          single
# 11                                               english          single
# 12     english (fluently), tagalog (fluently), japane...          single
# 13                english (fluently), spanish (fluently)          single
# 14                                               english          single
# 15                                               english          single
# 16     english (okay), french (poorly), spanish (poor...          single
# 17                            english, japanese (poorly)          single
# 18     english (fluently), french (fluently), spanish...          single
# 19                                               english          single
# 20                 english, tagalog (poorly), c++ (okay)  seeing someone
# 21                             english, spanish (poorly)          single
# 22                                    english (fluently)          single
# 23                    english (poorly), spanish (poorly)          single
# 24     english (fluently), french (okay), german (poo...          single
# 25                                               english          single
# 26                                               english          single
# 27                               english, other (poorly)          single
# 28     english (fluently), spanish (okay), portuguese...          single
# 29                                               english          single
# ...                                                  ...             ...
# 18801                                            english          single
# 18802                                            english          single
# 18803                                            english          single
# 18804                english (fluently), japanese (okay)          single
# 18805                                 english (fluently)          single
# 18806                                            english  seeing someone
# 18807                                            english          single
# 18808             english (fluently), spanish (fluently)          single
# 18809                 english (fluently), spanish (okay)          single
# 18810  english (fluently), french (okay), yiddish (po...          single
# 18811                                 english (fluently)          single
# 18812                                            english          single
# 18813                english (fluently), polish (poorly)          single
# 18814  english (fluently), russian (fluently), japane...          single
# 18815                        english (fluently), spanish          single
# 18816             english (fluently), italian (fluently)          single
# 18817                                            english          single
# 18818  english (fluently), french (poorly), hindi (po...          single
# 18819                                 english (fluently)          single
# 18820               english (fluently), chinese (poorly)          single
# 18821                                   english, russian          single
# 18822                 english (fluently), spanish (okay)          single
# 18823  english (fluently), polish (fluently), german ...          single
# 18824                                 english (fluently)          single
# 18825  english (fluently), spanish (fluently), french...          single
# 18826  english (fluently), polish (fluently), french ...          single
# 18827  english (fluently), hindi (poorly), french (po...          single
# 18828                                 english (fluently)          single
# 18829                                 english (fluently)          single
# 18830  english (fluently), spanish (poorly), chinese ...          single
#
#                          edu      fit  race_ethnicity  height_group
# 0        High School or less  not_fit        multiple     not_short
# 1        High School or less  not_fit           White     not_short
# 2      More than High School  not_fit           White         short
# 3                    unknown      fit           White         short
# 4      More than High School  not_fit           White     not_short
# 5      More than High School      fit           White     not_short
# 6                    unknown  not_fit           White     not_short
# 7      More than High School      fit           White     not_short
# 8      More than High School      fit           White         short
# 9      More than High School  not_fit           White     not_short
# 10     More than High School  not_fit           White     not_short
# 11     More than High School      fit        multiple     not_short
# 12       High School or less      fit        multiple     not_short
# 13     More than High School      fit           White         short
# 14     More than High School      fit           White     not_short
# 15     More than High School      fit        multiple     not_short
# 16     More than High School      fit           White     not_short
# 17     More than High School  not_fit           White         short
# 18       High School or less      fit           White     not_short
# 19       High School or less  not_fit           White     not_short
# 20       High School or less      fit           Asian         short
# 21     More than High School      fit           White         short
# 22       High School or less      fit           Asian         short
# 23                   unknown      fit        multiple     not_short
# 24     More than High School      fit           White     not_short
# 25     More than High School      fit           White     not_short
# 26       High School or less      fit           White     not_short
# 27     More than High School      fit           White         short
# 28     More than High School  not_fit           White         short
# 29     More than High School  not_fit           Black     not_short
# ...                      ...      ...             ...           ...
# 18801  More than High School      fit           White     not_short
# 18802  More than High School  not_fit           White         short
# 18803  More than High School  not_fit           White     not_short
# 18804  More than High School  not_fit           White     not_short
# 18805  More than High School      fit           White     not_short
# 18806  More than High School      fit           White     not_short
# 18807  More than High School      fit           White         short
# 18808  More than High School  not_fit          Latinx     not_short
# 18809  More than High School  not_fit          Latinx     not_short
# 18810  More than High School      fit        multiple         short
# 18811                unknown  not_fit           White         short
# 18812  More than High School      fit           Black     not_short
# 18813  More than High School  not_fit           White         short
# 18814  More than High School  not_fit           White         short
# 18815  More than High School      fit           Black     not_short
# 18816  More than High School      fit           White     not_short
# 18817                unknown  not_fit           White     not_short
# 18818                unknown  not_fit           Asian         short
# 18819                unknown      fit           White         short
# 18820  More than High School  not_fit           White     not_short
# 18821                unknown  not_fit           White     not_short
# 18822  More than High School  not_fit           White     not_short
# 18823  More than High School      fit           White     not_short
# 18824                unknown  not_fit        multiple     not_short
# 18825  More than High School  not_fit          Latinx     not_short
# 18826  More than High School  not_fit           White         short
# 18827  More than High School      fit           Asian     not_short
# 18828    High School or less      fit        multiple     not_short
# 18829  More than High School  not_fit           Asian     not_short
# 18830    High School or less      fit        multiple     not_short
#
# [18830 rows x 36 columns]

# %%
tf_vectorizer = CountVectorizer(max_features=2000, stop_words='english', ngram_range=(1,3))

print("Vectorizing text by word counts...")
tf_text = tf_vectorizer.fit_transform(profiles['essay0'])

tmp = tf_text.get_shape()
print("Our transformed text has", tmp[0], "rows and", tmp[1], "columns.")
# Out:
# Vectorizing text by word counts...
# Our transformed text has 18830 rows and 2000 columns.

# %% [markdown]
# #### See what words are being counted

# %%
tf_words = tf_vectorizer.get_feature_names()

print("The first few words (alphabetically) are:\n\n", tf_words[:500])
# Out:
# The first few words (alphabetically) are:
#
#  ['10', '10 years', '100', '11', '12', '13', '15', '18', '20', '20 years', '2010', '2011', '2012', '23', '24', '25', '30', '40', '50', '500', '500 words', '80', 'ability', 'able', 'abroad', 'absolutely', 'absurd', 'accent', 'accept', 'act', 'action', 'active', 'activities', 'activity', 'actually', 'add', 'addicted', 'admit', 'adult', 'adventure', 'adventures', 'adventurous', 'affectionate', 'afraid', 'africa', 'age', 'ago', 'agood', 'agreat', 'agree', 'ahead', 'air', 'alittle', 'alive', 'alot', 'amazing', 'ambitious', 'america', 'american', 'analytical', 'andhave', 'andi', 'andthe', 'angeles', 'animal', 'animals', 'anime', 'answer', 'anymore', 'apartment', 'apparently', 'appreciate', 'appreciation', 'approach', 'architecture', 'area', 'area native', 'area years', 'areas', 'aren', 'art', 'art music', 'artist', 'artistic', 'artists', 'arts', 'asia', 'asian', 'aside', 'ask', 'asked', 'aspects', 'ass', 'aswell', 'athlete', 'athletic', 'atleast', 'attempt', 'attend', 'attending', 'attention', 'atthe', 'attitude', 'attracted', 'attraction', 'attractive', 'australia', 'available', 'average', 'avid', 'avoid', 'aware', 'away', 'awesome', 'awhile', 'awkward', 'baby', 'background', 'backpacking', 'bad', 'balance', 'balanced', 'ball', 'band', 'bands', 'bar', 'bars', 'baseball', 'based', 'basically', 'basis', 'basketball', 'bass', 'bay', 'bay area', 'bay area native', 'bay area years', 'bayarea', 'beach', 'beaches', 'bear', 'beat', 'beautiful', 'beauty', 'bed', 'beer', 'begin', 'beginning', 'beliefs', 'believe', 'berkeley', 'best', 'best friend', 'best way', 'better', 'bicycle', 'big', 'big fan', 'biggest', 'bike', 'bikes', 'biking', 'bit', 'black', 'blah', 'blah blah', 'blessed', 'blue', 'blues', 'board', 'board games', 'boat', 'body', 'bonus', 'book', 'books', 'bored', 'boring', 'born', 'born raised', 'born raised san', 'boston', 'bottle', 'bought', 'box', 'boy', 'boys', 'brain', 'break', 'briggs', 'bright', 'bring', 'brings', 'brother', 'brought', 'brown', 'build', 'building', 'built', 'bunch', 'burning', 'burning man', 'business', 'busy', 'buti', 'buy', 'ca', 'cal', 'cali', 'california', 'called', 'calm', 'came', 'camp', 'camping', 'camping hiking', 'canada', 'capable', 'car', 'card', 'care', 'career', 'caring', 'carry', 'cars', 'case', 'casual', 'cat', 'catch', 'cats', 'cause', 'center', 'central', 'certain', 'certainly', 'challenge', 'challenges', 'challenging', 'chance', 'change', 'changed', 'changing', 'character', 'charming', 'chat', 'check', 'checking', 'cheese', 'chef', 'chemistry', 'chicago', 'child', 'childhood', 'children', 'chill', 'china', 'chinese', 'chocolate', 'choice', 'choose', 'circle', 'cities', 'city', 'class', 'classes', 'classic', 'classical', 'clean', 'clear', 'clever', 'click', 'climb', 'climbing', 'close', 'close friends', 'clothes', 'club', 'clubs', 'coast', 'coffee', 'cold', 'college', 'color', 'colorado', 'com', 'com watch', 'come', 'comedy', 'comes', 'comfort', 'comfortable', 'coming', 'committed', 'common', 'communication', 'community', 'companion', 'company', 'compassion', 'compassionate', 'competitive', 'complete', 'completely', 'complex', 'complicated', 'computer', 'computers', 'concert', 'concerts', 'confidence', 'confident', 'connect', 'connection', 'connections', 'conscious', 'consider', 'considerate', 'constant', 'constantly', 'contact', 'content', 'continue', 'control', 'conversation', 'conversations', 'cook', 'cooking', 'cool', 'core', 'couch', 'couldn', 'count', 'countries', 'country', 'county', 'couple', 'couple years', 'course', 'crazy', 'cream', 'create', 'created', 'creating', 'creative', 'creativity', 'crime', 'cross', 'cruz', 'cuddling', 'cultural', 'culture', 'cultures', 'cup', 'curiosity', 'curious', 'current', 'currently', 'currently working', 'cut', 'cute', 'cycling', 'cynical', 'dad', 'daily', 'damn', 'dance', 'dancing', 'dark', 'date', 'dates', 'dating', 'daughter', 'day', 'days', 'dc', 'dead', 'deal', 'death', 'decent', 'decide', 'decided', 'dedicated', 'deep', 'deeply', 'definitely' ...

# %% [markdown]
# #### See an example of how a profile's text is encoded
# - `n` is the profile number you want to look at. Change the value of `n` and re-run the code to see different profiles.
# - Note that only some of the words are counted. This is because we set `max_features=1000` in the vectorizor function, so it is only counting the 1,000 most common words and ignoring the rest.
#     - You can change that number to be bigger or smaller and see what happens.
#     - We found in Lab 1 that 1,000 is a good choice for this data because words less popular than that show up in less than 1% of all profiles.

# %%
n = 6

def show_vector(x, words):
    rows,cols = x.nonzero()
    for row,col in zip(rows,cols):
        print(words[col], '\t', x[row,col].round(2))

print('Profile text:\n', documents[n])
print('\nTF (count) vector:')
show_vector(tf_text[n], tf_words)
# Out:
# Profile text:
#  some of my favorite things:riding my motorcycle on curvy roadscurling up with the next book in the seriesfinding great photographsbuilding thingsjoking around with my friends, finding funny momentsthe starswindy daysliving near the beachlove and compassionmusiccooking dinner with a friendsometimes i'll take a different route, just to see where itgoes.my photos are available on facebook, for a peak of some of thoseunguarded moments :p
#
# TF (count) vector:
# moments 	 1
# facebook 	 1
# available 	 1
# photos 	 1
# dinner 	 1
# near 	 1
# finding 	 1
# great 	 1
# book 	 1
# motorcycle 	 1
# riding 	 1
# friends 	 1
# ll 	 1
# different 	 1
# just 	 1
# funny 	 1
# things 	 1
# favorite 	 1

# %% [markdown]
# ## Section 3: LDA Topic Model
#
# - LDA stands for Latent Dirichlet Allocation. The statistical math behind it is complicated, but its goals are simple:
#     - find groups of words that often show up together and call those groups topics.
#     - find topics that can be used to tell documents apart, i.e. topics that are in some documents but not others.
# - LDA is the most popular method for topic modeling.
# - [Learn more](https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation) about LDA
#
# ### Step 1: Decide how many topics we want to find
# - We must tell LDA how many topics we want it to look for (we did this above with the `ntopics` variable.

# %%
#how many topics we want our model to find
ntopics = 25

#how many top words we want to display for each topic
nshow = 40

# %% [markdown]
# ### Step 2: Run the LDA algorithm
# - LDA can be a little slow. We'll use a faster method later on.
# - Set `n_jobs=` to the number of processors you want to use to compute LDA. If you set it to `-1`, it will use all available processors.

# %%
model = LatentDirichletAllocation(n_components=ntopics, max_iter=10, 
                                  learning_method='online', n_jobs=2,
                                 random_state=seed)

print('Performing LDA on vectors. This may take a while...')
lda = model.fit(tf_text)
lda_topics = lda.components_

print('Done!')
# Out:
# Performing LDA on vectors. This may take a while...
# Done!

# %%
lda_topics.shape
#What do these dimensions mean?
# Out:
# (25, 2000)

# %%
filename = 'lda_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ## Section 4: Interpret Topics
# #### Some helper functions
# Don't worry about how these work right now. Just run them and scroll down. We'll use them to make our analysis easier later on.

# %%
def describe_topic(topic, feature_names, n_words=10):
    words = []
    # sort the words in the topic by importance
    topic = topic.argsort() 
    # select the n_words most important words
    topic = topic[:-n_words - 1:-1]
    # for each important word, get it's name (i.e. the word) from our list of names
    for i in topic:
        words.append(feature_names[i])
    # print the topic number and its most important words, separated by spaces
    return " ".join(words)

def display_topics(components, feature_names, n_words=40):
    # loop through each topic (component) in the model; show its top words
    for topic_idx, topic in enumerate(components):
        print("Topic {}:".format(topic_idx), 
              describe_topic(topic, feature_names, n_words))
    return

def find_intersection(idxa, idxb, n):
    a = set()
    b = set()
    both = set()
    i = 0
    while len(both) < n:
        a.add(idxa[i])
        b.add(idxb[i])
        both = a.intersection(b)
        i += 1
    return list(both)

def compare_topic_words(topics, a, b, words, how='overlap', n_words=nshow):
    b_sort = False
    if how == 'difference':
        b_sort = True
    
    dfa = pd.DataFrame(topics, columns=words).T
    idxa = dfa.sort_values(by=a, ascending=False).index.values
    idxb = dfa.sort_values(by=b, ascending=b_sort).index.values
    both = find_intersection(idxa, idxb, n=n_words)
    
    out = how + ' between ' + str(a) + ' and ' + str(b) + ':'
    for w in both:
        out += ' ' + w
    print(out)
    return

def blue_matrix(cells, xl, yl, x_labels=None):
    n = cells.shape[0]
    plt.figure()
    fig, ax = plt.subplots(figsize=(8,8))
    plt.imshow(cells, cmap='Blues')
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top') 
    if x_labels is not None:
        plt.xticks(range(n), x_labels)
    else:
        plt.xticks(range(n))
    plt.yticks(range(n))
    plt.ylabel(yl)
    plt.xlabel(xl)
    # show a colorbar legend
    plt.colorbar()
    #plt.title('Correlation between Topics', fontsize=25)
    plt.savefig('correl.png')
    return

# %% [markdown]
# ### Step 1: Show our topics with the top words in each

# %%
display_topics(lda_topics, tf_words, n_words=15)
# Out:
# Topic 0: bay area bay area east coast east coast bars grew years new living sf city west lived
# Topic 1: like don ll know want let need kids things think care don like ok stuff won
# Topic 2: things new love life try like enjoy trying new things hard work random friends learning make
# Topic 3: seen morning passions fiction pool worry things love complex sun possibly doors whiskey mlooking cross beliefs
# Topic 4: im love cook dont physical hit musician hey trust dad eat lol years old years despite
# Topic 5: life love time world people make live laugh enjoy happy work try day way living
# Topic 6: love like going enjoy hiking sports movies music easy outdoors good friends easy going watching fun
# Topic 7: self words lover jokes man curious romantic honest women stand ass love soul honesty young
# Topic 8: music games playing listening cars board drinking band pleasure motorcycles pursue italian board games ride win
# Topic 9: open life minded fun open minded passionate humor love looking creative sense loving great music enjoy
# Topic 10: born years raised moved ago born raised school years ago california lived sf south college grew moved bay
# Topic 11: woman dance man looking coffee single tall drink called short values class yes hi lady
# Topic 12: time humor good sense sense humor got spend geek like bit york ve new york things sarcastic
# Topic 13: ve really just time working recently video bit games work year think lot oh school
# Topic 14: like think people just don know say things really pretty ll way little look nice
# Topic 15: sure 10 grad grad school level 10 years constantly equally pop save summarize visit fully lack asian
# Topic 16: lot free fun cool little spend crazy bit people having living stuff free time doing laughing
# Topic 17: life love good food live great new world places friends experiences music family day like
# Topic 18: ve like feel native movies books told eating art later update long film says walks
# Topic 19: old relationship year long looking age intelligent term figure year old interested long term 20 life idea
# Topic 20: ask know just want questions want know early say just ask grown star know just discover wall wantto
# Topic 21: san francisco san francisco moved city went lived years grew new just moved just ve moved san college
# Topic 22: usually sf friends girl forward dinner months family travel leave moved sf awesome looking weekend moved
# Topic 23: like looking good just fun people time know want person guy meet really friends don
# Topic 24: new people meet meeting new people meet new meeting new friends meeting new people ready meet new people interesting new friends just haha

# %% [markdown]
# #### Short Answer:
# - Pick three topics.
# - Look at the words that make up each one. Say which one it is, and briefly answer these questions about it (3-5 sentences per topic):
#     - What does the topic seem to be about?
#     - If someone used most of those words together, what might they be talking about?
#     - Do any of the other topics seem similar to this one?

# %% [markdown]
# **Write your response here:**
# ....

# %% [markdown]
# ### Step 2: Examine the words that make two topics similar or different
# - We can also compare two topics to each other by looking at words that are common in both, or words that are common in one but not the other.
# - Try changing `topic_a` and `topic_b` to different topic numbers.
# - Notice the `how` option will let you see either the `overlap` or `difference` between two topics
#     - Notice also that the difference between topics a and b is not the same as between b and a

# %%
topic_a = 23
topic_b = 24

compare_topic_words(lda_topics, topic_a, topic_b, tf_words, how='overlap', n_words=nshow)
compare_topic_words(lda_topics, topic_a, topic_b, tf_words, how='difference', n_words=nshow)
compare_topic_words(lda_topics, topic_b, topic_a, tf_words, how='difference', n_words=nshow)
# Out:
# overlap between 23 and 24: meet consider want hang kind work friend smart enjoy life guy wanna interesting job really outgoing friendly love things way right person help try ll happy just people honest date message family like having easy know friends dating going open
# difference between 23 and 24: website exciting good people obviously mature gotta wait tobe bright surf decide grounded feeling shy sunday stupid local agreat medical people know waste make friends currently working parties plenty importantly wanted guy likes fish kind person typical getting know couch rarely try make searching knows use having good toknow
# difference between 24 and 23: africa thebay paint schedule haha colorado names teaching tried look like undergrad guitar play guitar single poly lessons looking new adult finishing years love inside andhave finish moved bay area new experiences iwould master months ago played beliefs happily snowboarding case dad fear love meeting boys swimming yoga marriage

# %% [markdown]
# ### Step 3: Interpret these topics
# #### Short Answer
# - This part is for you to do: code can't do it for you.
# - Try to come up with a short, catchy name for each topic and write it down.
#     - For example, if the words were "san francisco city moved living born years raised lived live", you might call it "places lived" because the topic seems to be about where people currently live (San Francisco) and where they were born / raised / moved from.

# %% [markdown]
# **Write your response here:**
# ...

# %% [markdown]
# ### Step 4: Check whether your interpretations match with the text
#
# #### Helper functions
# - Run this code and scroll down.
# - You don't need to understand these details right now.

# %%
def get_profiles_from_topics(data, transformed, topic_a, topic_b=None, pick_from=10):
    #get our data ready
    df = pd.DataFrame(transformed)
    df = df.sort_values(by=topic_a, ascending=False)
    n = df.shape[0]
    
    if topic_b is None:
        #if we only want things high in one topic, take randomly from the top
        keep = df.head(pick_from).sample(1)
        pid = keep.index.values[0]
    else:
        #if we want things high in two topics, find them and pick one of the top
        idxb = df.sort_values(by=topic_b, ascending=False).index.values
        both = find_intersection(df.index.values, idxb, pick_from)
        keep = df.loc[both, :].sample(1)
        pid = keep.index.values[0]    
        
    #output text to show our results
    match_text = 'Profile number ' + str(pid)
    match_text += ' has more of topic ' + str(topic_a)
    match_text += ' than {:.2f}%'.format(100 - (np.where(df.index==pid)[0][0] / n)*100)
    match_text += ' of other profiles'
    if topic_b is not None:
        match_text += ' and more of topic ' + str(topic_b)
        match_text += ' than {:.2f}%'.format(100 - (np.where(idxb==pid)[0][0] / n)*100)
        match_text += ' of other profiles.'
        
    #print results
    text = data[pid]
    print(match_text)
    print('Here is the text:\n\n', text)
    return

def visualize_profile(profile_topics, profile_id):
    # plot a stem diagram for a single profile
    plt.figure(figsize=(8,4))
    plt.xticks(range(profile_topics.shape[1]))
    plt.xlabel('Topic number')
    plt.ylabel('How much of profile is about each topic')
    plt.title('Profile #'+str(profile_id))
    plt.stem(profile_topics[profile_id,:])
    #plt.savefig()
    return

# %% [markdown]
# #### Calculate what portion of each profile is about each topic

# %%
profile_topics = lda.transform(tf_text)

# %% [markdown]
# #### Look at the text of a profile that has a lot of a particular topic
# - This function randomly picks one of the top few profiles for a topic, so each time you run it you will see a different example.
#     - If you want it to pick from more or less topics, change the value of `pick_from`
#     - If you want to see a different topic, change the value of `topic_a`
#     - **Hint:** you can press `ctrl`+`enter` over and over to keep re-running the code in this cell.

# %%
get_profiles_from_topics(profiles['essay0'], profile_topics, topic_a=11, pick_from=20)
# Out:
# Profile number 24 has more of topic 11 than 99.95% of other profiles
# Here is the text:
#
#  i can be extroverted and charming and yet enjoy living alone in mysanctuary of an apartment. i have a strong and dominant personalitythat is tempered by deep and stable emotions. i am comfortable withmyself and my flaws and am not above trying to work at selfbetterment. i'm looking for a unique woman who is modest about herbeauty, values a healthy and active lifestyle, and is independentbut willing to open up to a little dependence.

# %% [markdown]
# #### Look at the text of a profile that matches two topics well at the same time
# - Note that some topics might not happen together very often. If this is the case, the examples we find of both together might not be very good.

# %%
get_profiles_from_topics(profiles['essay0'], profile_topics, topic_a=17, topic_b=24)
# Out:
# Profile number 16109 has more of topic 17 than 98.37% of other profiles and more of topic 24 than 96.91% of other profiles.
# Here is the text:
#
#  i am a outgoing person looking to meet new friends.

# %% [markdown]
# #### See how much of a profile is about each topic
# - Try looking at some of the profiles you just found:
#     - Make the `pid` equal to the profile number from above.

# %%
pid =1000
visualize_profile(profile_topics, profile_id=pid)

# %%
pid =90
visualize_profile(profile_topics, profile_id=pid)

# %% [markdown]
# ## Section 5: Topic Quality
# Let's see how good the topics we found are.
#
# ### Step 1: See if the topics are each about different things.
# We want each topic to be about something different than the other topics. We can check this by comparing the words in each topic to the words in all the others. How to interpret:
# - Each square shows how similar two topics are. Darker means more similar, and lighter means more different.
# - The square in the very top left shows how similar topic 0 is to topic 0 (i.e. how similar it is to itself).
# - The square next to it in the top row shows how similar topic 0 is to topic 1, and so on.
# - For any two topics, you can see how similar they are by finding their numbers on the edges and seeing where they intersect.

# %%
def plot_topics(components):
    sim = cosine_similarity(components)
    blue_matrix(sim, xl='Topic number', yl='Topic number')
    return

plot_topics(lda_topics)

# %% [markdown]
# ### Step 2: See if different topics show up in different profiles
# The point is to tell profiles apart based on what topics they're about, so we need to check whether the topics appear in different profiles.
# - This shows us something that looks similar to the topic similarity we saw before, but this time:
#     - We **don't** compare topics based on which words they use
#     - We **do** compare topics based on how often they appear in the same profile as one another

# %%
def topic_cooccurance(topics):
    co = pd.DataFrame(topics).corr()
    blue_matrix(co, xl='Topic number', yl='Topic number')

topic_cooccurance(profile_topics)

# %% [markdown]
# #### Note that the topics are mostly uncorrelated.
# - The cells in the figure above are mostly very light blue
# - This doesn't mean that, for instance, topic 1 and 2 never show up in the same profile.
# - It does mean, however, that seeing any particular topic doesn't mean we're especially likely to also see any other topic.
#
# #### Reflect:
# - Why is the diagonal line so dark? Write a sentence or two.

# %% [markdown]
# **Write your response here:**
# ....

# %% [markdown]
# ## Section 6: Topic Popularity
#
# #### Helper functions to visualize and compare topics
# - Run this code and scroll down. The details of how it works aren't our focus right now.

# %%
def common_topics_bars(topics):
    popularity = pd.DataFrame(topics).mean()
    popularity = popularity.rename_axis('Topic')
    popularity = popularity.sort_values(ascending=False)
    popularity.plot.bar(title='Topic popularity')
    return

def rank_groups(data, trait, topic):
    groups = data[trait].value_counts().index.values
    result = {}
    
    for g in groups:
        result[g] = data[data[trait] == g][topic].mean()
    
    r = pd.DataFrame.from_dict(result, orient='index')
    r.columns = [topic]
    r = r.sort_values(by=topic, ascending=False)
    
    return r.round(3)

def top_topics(data, trait, value, n_top_topics=3, distinctive=False):
    topics = [col for col in data if col.startswith('topic_')]
    vals = {}
    means = {}
    if distinctive:
        for t in topics:
            means[t] = data[t].mean()
    else:
        for t in topics:
            means[t] = 1
    
    data = data[data[trait] == value]
    
    for t in topics:
        vals[t] = data[t].mean() / means[t]
    vals = pd.DataFrame.from_dict(vals, orient='index')    
    vals = vals.sort_values(by=0, ascending=False).head(n_top_topics)

    return list(vals.index.values)

# %% [markdown]
# ### Overall most common topics

# %%
common_topics_bars(profile_topics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-99bd850bb29f> in <module>()
# ----> 1 common_topics_bars(profile_topics)
#
# NameError: name 'profile_topics' is not defined

# %% [markdown]
# ### Who is a topic most popular with?

# %% [markdown]
# #### Step 1: Merge our information about topics with our information about people

# %%
topic_info = pd.DataFrame(profile_topics).add_prefix('topic_')
together = profiles.merge(topic_info, left_index=True, right_index=True)
together.to_csv('topics_profiles.csv')

# %% [markdown]
# #### Step 2: See the groups that have the most text about a given topic
# - The numbers here show how much of a profile, on average, is about a specific topic.
#
# #### Play around with the code in the next few cells:
# - Pick one of the traits we have data for. Here are the options (information we know about users from their profiles):
#     - `age_group` categories: ['10', '20', '30', '40', '50']
#     - `body` categories: ['average', 'fit', 'thin', 'overweight', 'unknown']
#     - `alcohol_use` categories: ['yes', 'no']
#     - `drug_use` categories: ['yes', 'no']
#     - `edu` (highest degree completed) categories: ['`<HS`', 'HS', 'BA', 'Grad_Pro', 'unknown']
#     - `race_ethnicity` categories: ['Asian', 'Black', 'Latinx', 'White', 'multiple', 'other']
#     - `height_group` (whether someone is over or under six feet tall) categories: ['under_6', 'over_6']
#     - `industry` (what field they work in) categories: ['STEM', 'business', 'education', 'creative', 'med_law', 'other']
#     - `kids` (whether they have children) categories: ['yes', 'no']
#     - `orientation` categories: ['straight', 'gay', 'bisexual']
#     - `pets_likes` (what pets they like) categories: ['both', 'dogs', 'cats', 'neither']
#     - `pets_has` (what pets they have) categories: ['both', 'dogs', 'cats', 'neither']
#     - `pets_any` (whether they have pets or not) categories: ['yes', 'no']
#     - `religion` categories: ['christianity', 'catholicism', 'judaism', 'buddhism', 'none', 'other']
#     - `sex` categories: ['m', 'f']
#     - `smoker` categories: ['yes', 'no']
#     - `languages` categories: ['multiple', 'English_only']
# - Change the topics and values in the code in the next few cells to explore how the trait you chose relates to the topics.
#
# #### Short Answer:
# - Write down which trait(s) you chose to look at, and what you learned about different groups of people from the topics they used. What topics do they have in common? What topics make them different? Does this make sense given the groups? Why or why not? Remember: we interpreted the topics above, so explain your findings in terms of content, not just topic numbers. Write 1-2 paragraphs.

# %%
rank_groups(together, trait='edu', topic='topic_0')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-eeb77e5b9bba> in <module>()
# ----> 1 rank_groups(together, trait='edu', topic='topic_0')
#
# NameError: name 'together' is not defined

# %% [markdown]
# #### Step 3: See the topics that are most common for a given group
# - This example shows most common topics for different education groups.
# - You can change the arguments to compare different groups.

# %%
#show most popular topics for High School graduates
top_topics(data=together, trait='race_ethnicity', value='Latinx', n_top_topics=7)
# Out:
# ['topic_6',
#  'topic_14',
#  'topic_23',
#  'topic_5',
#  'topic_2',
#  'topic_17',
#  'topic_13']

# %%
#show most popular topics for High School graduates
top_topics(data=together, trait='edu', value='BA', n_top_topics=3)
# Out:
# ['topic_0', 'topic_1', 'topic_2']

# %% [markdown]
# #### Step 4: See the topics that distinguish a group from other groups
# - This example shows most distinctive topics for different education levels.
# - You can change the arguments to compare different groups

# %%
top_topics(data=together, trait='edu', value='HS', n_top_topics=3, distinctive=True)
# Out:
# ['topic_0', 'topic_1', 'topic_2']

# %%
top_topics(data=together, trait='edu', value='Grad_Pro', n_top_topics=3, distinctive=True)
# Out:
# ['topic_0', 'topic_1', 'topic_2']

# %% [markdown]
# **Write your response here:**
# ....

# %% [markdown]
# # Section 7: NMF Topic Model
# - NMF is an alternative to LDA
# - NMF stands for Non-Negative Matrix Factorization.

# %% [markdown]
# ### Expand for more on how NMF works

# %% [markdown]
# - `Factoring` is something you may have done in math class before, for example:
#     - $ 10 $ can be factored as $ 2 \times 5 $
#     - $ x^2+3x+2 $ can be factored as $ (x+2)(x+1)$
# - When we convert the text into numbers for the computer, it gets stored as something called a `matrix`.
#     - The matrix is `non-negative` because we can't have negative numbers of words: all the word counts are zero or more.
# - It is not important right now how exactly we find factors for these matrices, but if you're curious, you can learn more about it in a Linear Algebra class.
# - It turns out that finding factors for text is a really good way of finding topics. This makes sense intuitively: factors are simple things we can combine to get the more complicated output, and topics are simple things people combine to write profiles.
# - [Learn more](https://en.wikipedia.org/wiki/Non-Negative_matrix_factorization#Text_mining) about NMF.

# %% [markdown]
# ### Step 1: Convert text to numbers the computer understands
# - NMF takes "tf-idf vectors" as input. Tf-idf stands for "text frequency - inverse document frequency."
#     - Text frequency is the same as the count vectors we used for LDA above: how often does each word appear in the text?
#     - Inverse document frequency means we divide ("inverse") by the number of documents the word is in. (If everyone uses the word, it isn't very helpful for figuring out what makes people different. So this measurement looks for words that are used a lot in some documents, and not at all in others.)

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=2000, stop_words='english', ngram_range=(1,3))

print("Vectorizing text by TF-IDF...")
tfidf_text = tfidf_vectorizer.fit_transform(documents)

tmp = tfidf_text.get_shape()
print("Our transformed text has", tmp[0], "rows and", tmp[1], "columns.")
# Out:
# Vectorizing text by TF-IDF...
# Our transformed text has 18830 rows and 2000 columns.

# %% [markdown]
# #### The features are mostly the same as count vectors, because they are just the common words in the text

# %%
tfidf_words = tfidf_vectorizer.get_feature_names()
print("The first few words (alphabetically) are:\n", tfidf_words[:20])
# Out:
# The first few words (alphabetically) are:
#  ['10', '10 years', '100', '11', '12', '13', '15', '18', '20', '20 years', '2010', '2011', '2012', '23', '24', '25', '30', '40', '50', '500']

# %% [markdown]
# #### The values are different: the counts have been divided by the documents they show up in

# %%
n = 4

print('Profile text:\n', documents[n])
print('\nTF-IDF vector:')
show_vector(tfidf_text[n], words=tfidf_words)
# Out:
# Profile text:
#  i was born in wisconsin, grew up in iowa, and moved to californiathree years ago for a combination of work opportunity and justwanting to live in sf. it took me a couple years to get to thepeninsula, but i'm glad i eventually got here. i'm passionate aboutpeople and have a wide variety of interests and talents.i'm also continually learning about myself. for example, i'mlearning very recently that as a result of spending all my timegrowing up, in college, and for the last five years focusing ongrowing my "deep relationship" skills, i'm not as good as ipreviously thought at initializing friendships/relationships. iguess that isn't all a bad thing since the "first impression" thingonly really happens once with each person. :)as a result, i love my friends, i've got a lot of deep friendships,and know how much richer a friendship can get as it getsdeeper.i'm passionate about music, i play the guitar, write songs (lessnow than before), write plays (more now than before), want to learnfrench and asl, am pretty good for an amateur ballroom dancer, cando almost everything moderately well (seriously, no joke), lovebright ties and shoes, am a jacket and jeans person, and absolutelylove figuring out how people tick. i think i'm pretty cool and wishmore people would be patient enough to take the time to seethat.every friend i've ever had say i'm nothing like anyone else. so idon't come off like anyone else. i'm my own person. and i'm proudof that.
#
# TF-IDF vector:
# love 	 0.04
# think 	 0.06
# say 	 0.07
# like 	 0.08
# friend 	 0.09
# got 	 0.17
# shoes 	 0.13
# really 	 0.06
# deep 	 0.21
# work 	 0.06
# cool 	 0.09
# songs 	 0.13
# pretty 	 0.13
# people 	 0.1
# sf 	 0.07
# live 	 0.07
# years 	 0.19
# music 	 0.06
# play 	 0.07
# guitar 	 0.1
# ve 	 0.11
# know 	 0.06
# play guitar 	 0.13
# ve got 	 0.11
# born 	 0.08
# grew 	 0.08
# moved 	 0.07
# ago 	 0.09
# opportunity 	 0.12
# took 	 0.11
# couple 	 0.1
# glad 	 0.14
# eventually 	 0.13
# passionate 	 0.17
# wide 	 0.12
# variety 	 0.12
# interests 	 0.1
# learning 	 0.09
# example 	 0.13
# recently 	 0.08
# result 	 0.27
# spending 	 0.1
# college 	 0.08
# relationship 	 0.09
# skills 	 0.12
# good 	 0.11
# thought 	 0.1
# friendships 	 0.27
# relationships 	 0.11
# isn 	 0.1
# bad 	 0.1
# thing 	 0.08
# happens 	 0.12
# person 	 0.19
# friends 	 0.06
# lot 	 0.07
# friendship 	 0.13
# write 	 0.18
# plays 	 0.14
# want 	 0.06
# seriously 	 0.09
# joke 	 0.11
# jeans 	 0.14
# figuring 	 0.14
# patient 	 0.12
# time 	 0.05
# idon 	 0.12
# come 	 0.09
# years ago 	 0.1
# couple years 	 0.13
# pretty good 	 0.13

# %% [markdown]
# ### Step 2: Build a topic model using NMF
#
# - NMF is faster than LDA and often works a little better for small documents like we have here.

# %%
model = NMF(n_components=ntopics, alpha=.1, l1_ratio=.5, init='nndsvd', random_state=seed)

print('Performing NMF on vectors...')
nmf = model.fit(tfidf_text)
nmf_topics = nmf.components_

print('Done!')
# Out:
# Performing NMF on vectors...
# Done!

# %%
nmf_filename = 'nmf_model.sav'
pickle.dump(model, open(nmf_filename, 'wb'))

# %%
nmf_profile_topics= nmf.transform(tfidf_text)

# %%
nmf_topic_info = pd.DataFrame(nmf_profile_topics).add_prefix('topic_')
nmf_together = profiles.merge(nmf_topic_info, left_index=True, right_index=True)
nmf_together.to_csv('nmf_topics_profiles.csv')

# %% [markdown]
# ### Step 3: Show our topics with the top words in each

# %%
display_topics(nmf_topics, tfidf_words, nshow)
# Out:
# Topic 0: don ve think people really ll time say way make lot little right world self pretty thing best bit probably things feel need day better kind long believe let got profile read man try tell maybe look great come mind
# Topic 1: moved years sf ago city school ve lived years ago year grew moved sf college went california recently originally living spent months recently moved job just moved york nyc la new york ve lived boston new south grad graduated couple went school old worked chicago got year ago
# Topic 2: new people new people meet meet new meeting meet new people meeting new meeting new people looking meet looking meet new city new places places new friends meet people love meeting new york york like meet experiences new experiences exploring interesting love meet traveling interested explore interesting people meeting people site people like trying outgoing people love cool dating tomeet exploring new hey
# Topic 3: san francisco san francisco moved san moved san francisco living san living san francisco city living moved just moved san diego grew san diego native raised san live lived san born raised san raised san francisco just moved lived recently originally year university recently moved currently working explore angeles seattle hi exploring los angeles los art home company dream
# Topic 4: area bay bay area moved bay moved bay area native area native bay area native area years bay area years lived bay lived living east bay grew moved raised bay new years places working home offer exploring college originally place currently east recently live transplant inthe la oakland thebay area thebay year berkeley job
# Topic 5: im dont lol ive alot chill thats old kinda really lets years old say names shy time hi wanna haha single real cause hit sports cool music message nice type hey make gentleman good time outgoing student tattoos 20 sure talk college
# Topic 6: like don like things like feel like really like stuff like think like going don feel like meet like people play people like like laugh watch movies like fun time like people like make like travel just like think hang like good like play going like stay life like eat things girls drink laugh like things dance cook active ilike
# Topic 7: love laugh travel love travel music love music outdoors love laugh love outdoors love life cook food sports love cook art love going life love world love love especially nature play make live people love love good love sports things love ilove great making love meet people laugh love traveling love people eat dance time love heart passionate
# Topic 8: easy going easy going going guy easy going guy pretty easy pretty easy going laid pretty like going love going earth try let laugh drama likes friendly simple enjoy going relaxed sense humor talk funny guy likes humor happy movie stay little trying spontaneous really gym sense guy loves say offer enjoys listener
# Topic 9: looking looking meet meet woman relationship share girl guy looking partner just looking single special looking fun looking forward friend man forward looking new hang date right looking meet new term intelligent explore maybe women looking woman hi great long term long time wants want dating lady confident real smart
# Topic 10: good humor sense sense humor good time good food food good sense good sense humor conversation time good conversation good company enjoy good good people like good pretty company love good listener good listener pretty good times great having good really good wine laugh good friends great sense beer great sense humor dry life good sarcastic bad friend good guy having honest
# Topic 11: life live enjoy live life living enjoy life things life world enjoying fullest share short simple love life enjoying life life short experiences positive life fullest believe living life want life love happy life like best important adventure loving experience day career offer great passion make journey passionate woman moment
# Topic 12: things new new things try trying try new trying new trying new things try new things learning places learning new things like things life learning new things doing new places learn things love like try learn new different exploring lot willing make doing things things enjoy simple simple things experience love learning little things like things lot things traveling restaurants pretty explore new hiking
# Topic 13: just just moved just ask ask moved trying just looking just like know just just got just moved san hang got just want really chill wanna say city start going message hit dude ll just maybe site far moved san let cool enjoying questions moved san francisco lol graduated started lets happens girl
# Topic 14: fun loving fun loving having fun having like fun looking fun adventurous outgoing smart caring loves fun like likes intelligent honest hang spontaneous times witty laugh funny little lot fun party stuff interesting best lets exciting doing passionate big energetic making girl make romantic home try
# Topic 15: born raised born raised raised san born raised san raised bay raised san francisco went sf california school bay oakland college cal ca lived currently years went school sports berkeley city boston came south sanfrancisco san family boy state graduated east bay american chinese giants bayarea mother country midwest
# Topic 16: hard working hard working work hard play hard play play hard work hard play harder worker time ambitious adventurous loves believe caring currently working man party currently try driven active goals honest playing dedicated professional motivated works goal career make passionate lifestyle startup romantic personal loyal living
# Topic 17: enjoy music time movies playing hiking sports watching games outdoors reading cooking going spend play art traveling camping biking food live working running active rock activities dancing video guitar fan beach wine listening hanging live music shows travel snowboarding day video games
# Topic 18: work progress lot work hard school live play week time work time day company travel tech job sleep try outside balance busy gym home weekends trying industry sf days run bike hours went drink weekend cook work hard play ride kids eat startup free
# Topic 19: person type person type kind person like laid kind person person love earth honest outgoing try pretty loves shy consider funny simple chill better people loyal active likes caring think special quiet friendly hang enjoys positive genuine believe iam nice humble definitely passionate creative
# Topic 20: know want want know ask don know don message know just just ask getting know don want know want talk ll let getting let know wanna like know say tell dont send know people feel free people know just want want meet shy feel oh free questions lol hit really want profile thing chat need
# Topic 21: open minded open minded adventurous curious honest creative friendly relationship mind earth funny free open mind confident caring passionate independent book strong shy positive spontaneous patient different individual intelligent meeting ambitious kind interested humor loving warm times romantic respectful comfortable tend long
# Topic 22: guy nice nice guy laid pretty guy looking funny laid guy earth kind guy kind going guy chill likes loves guy likes easy going guy guy loves guy like guy love girl simple cool pretty laid type good guy enjoys outgoing smart shy kinda regular typical sweet sports friendly decent laugh honest active
# Topic 23: friends family family friends friends family new friends close hanging important great spending hanging friends make make new make new friends hang good friends time friends close friends spending time group make friends loyal friends say new oriented best dinner value lucky career making job home travel circle party awesome social visit values
# Topic 24: coast east east coast west west coast transplant east bay grew bay school originally moving living asia came miss left mid nyc ny summer great home culture humor college laid california south adventure city went warm went college grad school jersey exploring start enjoying europe

# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

# %%
pyLDAvis.sklearn.prepare(final_ls, corpus, dictionary)

# %% [markdown]
# ### Step 4: Compare topics to each other
# We can compare topics visually by plotting the similarity of each topic's chosen words to each other topic.

# %% [markdown]
# get_profiles_from_topics(profiles['essay0'], nmf_profile_topics, topic_a=11, topic_b=12)

# %%
nmf_profile_topics.shape

# %%
common_topics_bars(nmf_profile_topics)

# %%
plot_topics(nmf_profile_topics)

# %%
topic_cooccurance(nmf_profile_topics)

# %%
topic_cooccurrance(lda_topics)

# %%
top_topics(data=nmf_together, trait='race_ethnicity', value='Latinx', n_top_topics=7)

# %% [markdown]
# #### Examine the words that make two topics similar or different
# We can also compare two topics to each other by looking at words that are common in both, or words that are common in one but not the other. Try changing topic_a and topic_b to different topic numbers.

# %%
topic_a = 3
topic_b = 21

compare_topic_words(nmf_topics, topic_a, topic_b, tfidf_words, n_words=nshow, how='overlap')
compare_topic_words(nmf_topics, topic_a, topic_b, tfidf_words, n_words=nshow, how='difference')
compare_topic_words(nmf_topics, topic_b, topic_a, tfidf_words, n_words=nshow, how='difference')

# %% [markdown]
# ### Step 5: Interpret these topics
# - This part is for you to do: code can't do it for you.
# - Look at the list of important words for each topic, and think about these questions. (No writing required.)
#     - What do the words have in common?
#     - What could someone write that would use most of those words?
#     - What does this topic seem to be about?
# - Try to come up with a short, catchy name for each topic.
#     - For example, if the words were "san francisco city moved living born years raised lived live", you might call it "places lived" because the topic seems to be about where people currently live (San Francisco) and where they were born / raised / moved from.
# - Try other numbers of topics.
#     - If the topics seem repetitive, you might want to try looking for fewer topics.
#     - If the topics seem confusing or vague, you might want to try looking for more topics (so that they can be more specific).

# %% [markdown]
# ### Step 6: Compare the topics from LDA and NMF
#
# #### Helper function to make a graph for us

# %%
def plot_confusion(x, y, x_label='', y_label='', sort=True):
    n = x.shape[0]
    corrs = cosine_similarity(x, y)
    topic_similarity = pd.DataFrame(corrs)
    new_order=None
    
    if sort:
        matches = []
        pairs = {}

        for i in range(n):
            for j in range(n):
                tmp = {}
                tmp['i'] = i
                tmp['j'] = j
                tmp['match'] = corrs[i][j]
                matches.append(tmp)

        matches = pd.DataFrame(matches).sort_values(by='match', ascending=False)

        for row in matches.iterrows():
            i = row[1]['i']
            j = row[1]['j']
            if i not in pairs.keys():
                if j not in pairs.values():
                    pairs[i] = row[1]['j']

        new_order = list(range(n))
        for k in pairs.keys():
            new_order[int(k)] = int(pairs[k])

        topic_similarity = topic_similarity[new_order]

    blue_matrix(topic_similarity, xl=x_label, yl=y_label,
                x_labels=new_order)
    return

# %% [markdown]
# #### See how similar the words in each topic from LDA are to the words in each topic from NMF
# - The NMF topics are along the X axis and the LDA are along the Y axis.

# %%
plot_confusion(x = nmf_topics, x_label='NMF topic number',
               y = lda_topics, y_label='LDA topic number',
               sort=False)

# %% [markdown]
# #### We can also sort the topics so that the most similar ones are aligned

# %%
plot_confusion(x = nmf_topics, x_label='NMF topic number',
               y = lda_topics, y_label='LDA topic number',
               sort=True)

# %% [markdown]
# Look at the LDA and NMF topic words and the confusion matrix, and consider the following questions (no writing required):
# - Do any of the topics seem to be the same in both models?
# - Are some topics in one model but not the other?
# - Do the topics you get from one of the models make more sense than the ones you get from the other?

# %% [markdown]
# ## Section 8: What We Learned
# - Two statistical methods for topic modeling
#     - LDA
#     - NMF
# - Two ways to represent text as numbers
#     - TF / count vectors (counts of how often each word is used)
#     - TF-IDF vectors (counts of how often each word is used, divided by the number of documents they're used in)
# - How to think about and interpret the topics our models find
# - How to compare and relate different topics
# - Different ways to see the distribution of topics in profiles
# - Which topics are most popular with social categories of people
# - Which social categories of people discuss a topic most

# %% [markdown]
# #### Reflect
# - How is what we learned in this lab, using topic modeling, different from what we learned in the last lab, using just word frequencies? How is it similar? Write a paragraph explaining.

# %% [markdown]
# **Write your response here:**
# ....
